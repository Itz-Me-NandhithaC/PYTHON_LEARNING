# %% [markdown]
# # Python Data Structure
# - To collect multiple data in the form of Organised Structure
# ### Four Types of DATA STRUCTURE
# 1. List
# 2. Tuple
# 3. Sets
# 4. Dictionary ; key:value pairs

# %% [markdown]
# # 1.List
# - 1 Dimension
# - Heterogenous
# - Contains Duplicates
# - list=[]
# - Mutable
# - allows multiple elements
# - negative for slicing

# %% [markdown]
# ### Creating List

# %%
a=[12,34,"nandhitha",36] # Heterogeneous datatypes
a
# Out:
# [12, 34, 'nandhitha', 36]

# %% [markdown]
# ### Check Type

# %%
type(a)      ## check the type
# Out:
# list

# %% [markdown]
# ### Access the element

# %%
print(a[0])
# Out:
# 12

# %% [markdown]
# ### Negative indexing to access the element

# %%
print(a[-2])
# Out:
# nandhitha

# %% [markdown]
# ### Slicing using the :
# - [:] it prints all element from the list
# - last = n-1

# %%
print(a[:])
# Out:
# [12, 34, 'nandhitha', 36]

# %%
print(a[2:])
# Out:
# ['nandhitha', 36]

# %%
print(a[:2])
# Out:
# [12, 34]

# %%
print(a[2],a[-1])
# Out:
# nandhitha 36

# %%
b=[23,11,20,22]
print(b[-4:-1])
# Out:
# [23, 11, 20]

# %%
c=[23,11,20,22]
print(c[-1:-3])
# Out:
# []

# %% [markdown]
# ### What is Mutable?
# - change the value
# - change the value in future
# - we can update the list in future

# %%
m=["we","are","indians"]
print(m)
# Out:
# ['we', 'are', 'indians']

# %%
m[2]="Tamilans"

# %%
print(m)
# Out:
# ['we', 'are', 'Tamilans']

# %% [markdown]
# ## Method	Description
# - append()	Adds an element at the end of the list
# - clear()	Removes all the elements from the list
# - copy()	Returns a copy of the list
# - count()	Returns the number of elements with the specified value
# - extend()	Add the elements of a list (or any iterable), to the end of the current list
# - index()	Returns the index of the first element with the specified value (n-1)
# - insert()	Adds an element at the specified position
# - pop()	Removes the element at the specified position
# - remove()	Removes the first item with the specified value
# - reverse()	Reverses the order of the list
# - sort()	Sorts the list

# %% [markdown]
# ### append()
# - create list
# - append()
# - print()

# %%
lst_app=[1,2,3]
lst_app.append(4)
print(lst_app)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### index()
# - returns index(n-1) value
# - n=position given

# %%
lst=[1,2,3,4,5]
print(lst.index(4))
# Out:
# 3

# %% [markdown]
# ### count()
# - return times of repeat of given number from the list

# %%
lst_cou=[1,2,2,3,2,1,2]
print(lst_cou.count(2))
# Out:
# 4

# %% [markdown]
# # 2.SET
# - 1D
# - Not allowing of Duplicate values
# - Heterogenous
# - mutable

# %% [markdown]
# ### Creating the set

# %%
set_var=set()
set_var
# Out:
# set()

# %%
type(set_var)
# Out:
# set

# %%
set_var={"set","is","is","heterogenous",12,67,56}
set_var
# Out:
# {12, 56, 67, 'heterogenous', 'is', 'set'}

# %% [markdown]
# ### Trying Mutable in set

# %%
set_var[1]="hey"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 set_var[1]="hey"
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# ### Adding the element to the SETS
# - using add()

# %%
set_var.add("Hey")
set_var
# Out:
# {12, 56, 67, 'Hey', 'heterogenous', 'is', 'set'}

# %% [markdown]
# ### as the result
# - cant perform the indexing and slicing from the set
# - so,cant be update the date by position
# - but can by using the funtions()
#    - add()
#    - discard() etc,,,,,

# %%
set_var.discard("Hey")

# %%
set_var
# Out:
# {12, 56, 67, 'heterogenous', 'is', 'set'}

# %%
a=6
b=2
power=a**b
print(power)
# Out:
# 36

# %%
last=power%10

# %%
print(last)
# Out:
# 6

# %% [markdown]
# # 3.Tuple
# - 1D
# - heterogenous
# - allows duplicates
# - Unmutable
# - indexing and slicing are allowed

# %% [markdown]
# ### Creating the Tuple
# -using the ()

# %%
tup_cre=()
tup_cre
# Out:
# ()

# %% [markdown]
# ### Checking type

# %%
type(tup_cre)
# Out:
# tuple

# %% [markdown]
# ### slicing and indexing

# %%
print(tup_cre[2])
# Out:
# crevasse

# %%
print(tup_cre[1:4])
# Out:
# ('glacier', 'crevasse', 'fireweed')

# %% [markdown]
# ### tuple is immutable

# %%
tup_cre[1]=("nan")
tup_cre
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tup_cre[1]=("nan")
#       2 tup_cre
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # 4.Dictionary
# - 2D (because, "Key:value" paire represents "columns:row value")
# - Key:value pairs
# - value may duplicate, but key won't
# - dont craete the duplicate key,but you can create duplicate values
# - idexing and slicing are not possible
# - it is mutable (because it has the funciton to update in future cases)

# %% [markdown]
# ## creating Dictionary

# %%
cre_dict={}
cre_dict
# Out:
# {}

# %% [markdown]
# ### Check Type

# %%
type(cre_dict)
# Out:
# dict

# %% [markdown]
# ### values

# %%
cre_dict={"Name":"Nandhitha","Age":19,"Phone":1000000000}
cre_dict
# Out:
# {'Name': 'Nandhitha', 'Age': 19, 'Phone': 1000000000}

# %% [markdown]
# ### idexing and slicing

# %%
cre_dict[1:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cre_dict[1:2]
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# ### Mutable

# %%
cre_dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Phone'])

# %%
cre_dict.values()
# Out:
# dict_values(['Nandhitha', 19, 1000000000])

# %%
cre_dict.clear()

# %%
cre_dict
# Out:
# {}

# %% [markdown]
# ### 1.Create dictionary for DataFrame
# - don't, c_dict={"anu":5,"banu":3,"subz":7}
# - do c_dict={"anu":[5,3,4,6],"banu":[2,3,4,5],"subz":[0,7,5,3]}
# ### 2.Can import dict to pd for DateFrame
# - lets see

# %% [markdown]
# ### Makes mistake

# %%
# create dictionary
c_dict={"anu":5,"banu":3,"subz":7}
c_dict
# Out:
# {'anu': 5, 'banu': 3, 'subz': 7}

# %%
# importing padas for making the DataFrame
import pandas as pd

# %%
# making data frame using c__dict (created dictionary)
pd.DataFrame(data=c_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 # making data frame using c__dict (created dictionary)
# ----> 2 pd.DataFrame(data=c_dict)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...

# %% [markdown]
# This is because it just creating the single row and multiple columns👆🏻👆
# - so use the [] for more values

# %%
# creating another dictionary
student_mark={"Student":["Nandhitha","Ria","Yathra"],
              "Maths":[68,85,95],
              "Computer":[100,100,100],
              "Tamil":[85,85,86]}
student_mark
# Out:
# {'Student': ['Nandhitha', 'Ria', 'Yathra'],
#  'Maths': [68, 85, 95],
#  'Computer': [100, 100, 100],
#  'Tamil': [85, 85, 86]}

# %%
# importing pandas for DataFrame
import pandas as pd
# importing data ststudent_mark (dictionary
pd.DataFrame(data=student_mark)
# Out:
#      Student  Maths  Computer  Tamil
# 0  Nandhitha     68       100     85
# 1        Ria     85       100     85
# 2     Yathra     95       100     86

# %% [markdown]
# # END!!!
